# %% [markdown]
# # API's

# %% [markdown]
# Have you ever wondered how online flight search engines like **kayak** or expedia cater the best deals for you? How they manage to keep their data updated even if it means gathering data from hundreds of carriers?

# %% [markdown]
# The answer is with **API**s, acronym for Application Programming Interface.

# %% [markdown]
# With APIs we are able to retrieve data from remote websites. Sites like Google, Twitter, and Facebook all make certain data available to programmers through their Application Programming Interfaces — APIs. To use an API, you make a request to a remote web server, and retrieve the data you need.
#
# <img src='img/api.jpeg' width=500>
#
# But why use an API instead of a static data set you can download?
# APIs are useful in the following cases:
# - The data is changing quickly (stock price data,..)
# - You want a small piece of a much larger set of data (filter, requests, parameter)
# - calculations or preparations are done on the external system
#
# In cases like the ones above, an API is the right solution. Here, we will be querying a simple API to retrieve data about **Google Trends and Google Places**. Using an API will save us time and effort over doing all the computation ourselves.
#
# **API Requests in Python**
# APIs are hosted on web servers. When you type www.google.com in your browser’s address bar, your computer is actually asking the www.google.com server for a web page, which it then returns to your browser.
# APIs work much the same way, except instead of your web browser asking for a web page, your program asks for data. This data is usually returned in **JSON format**.

# %% [markdown]
# ## Google Trends

# %% [markdown]
# https://trends.google.com/trends

# %% [markdown]
# **Google trends** is a website that analyzes and lists the popular search results on Google search based on various regions and languages.

# %% [markdown]
# Can I get this data into my Jupyter Notebook?
# Here you will learn how to get trending results (and many more) from Google trends website using Python. You don’t need to manually search and copy the trending results, the Python API called pytrends does the job for you. Before getting started, let us take a look at the official documentation of the pytrends API. (https://pypi.org/project/pytrends/)

# %%
import time
import pandas as pd

# %% [markdown]
# First of all we need to import (install) the required libraries.

# %%
# pip install pytrends
from pytrends.request import TrendReq

# %% [markdown]
# You must **connect to Google** first because, after all, we are requesting the Google trending topics from Google Trends. For this, we need to import the method called TrendReq from pytrends.request library.

# %%
pytrend = TrendReq(hl='de',tz=360)
# https://sites.google.com/site/tomihasa/google-language-codes
# languages codes : hl=de ,hl='en-US'

# %% [markdown]
# ### Interest by region

# %%
pytrend.build_payload( kw_list=['Corona'], geo='DE', timeframe='today 3-m' )
# 'today 3-m' , '2019-12-14 2020-02-25'

# Interest by Region
df = pytrend.interest_by_region(resolution='REGION')
df.sort_values('Corona',ascending= False)
# Out:
#                         Corona
# geoName
# Niedersachsen              100
# Nordrhein-Westfalen        100
# Thüringen                  100
# Schleswig-Holstein          99
# Bayern                      98
# Hamburg                     98
# Baden-Württemberg           96
# Bremen                      94
# Sachsen                     94
# Rheinland-Pfalz             92
# Mecklenburg-Vorpommern      91
# Saarland                    91
# Brandenburg                 88
# Hessen                      85
# Sachsen-Anhalt              84
# Berlin                      81

# %% [markdown]
# The values are calculated on a scale from 0 to 100, where 100 is the location with the most popularity as a fraction of total searches in that location, a value of 50 indicates a location which is half as popular. A value of 0 indicates a location where there was not enough data for this term.

# %%
pytrend.related_queries()
# Out:
# {'Corona': {'top':                        query  value
#   0         deutschland corona    100
#   1             corona aktuell     91
#   2              corona zahlen     79
#   3              corona bayern     64
#   4                news corona     49
#   5                 nrw corona     48
#   6                 corona usa     36
#   7                 corona rki     33
#   8                 corona app     31
#   9       niedersachsen corona     27
#   10             corona berlin     27
#   11             corona regeln     25
#   12         fallzahlen corona     25
#   13            sachsen corona     23
#   14              corona karte     22
#   15  corona baden württemberg     22
#   16             hessen corona     21
#   17           schweden corona     21
#   18           corona weltweit     18
#   19            hamburg corona     18
#   20              corona virus     17
#   21               corona tote     17
#   22         corona infizierte     16
#   23     corona in deutschland     16
#   24    aktuelle corona zahlen     15,
#   'rising':                                   query  value
#   0                       corona warn app  24350
#   1                    corona lockerungen  22750
#   2                        tönnies corona  15150
#   3                corona lockerungen nrw  13800
#   4             corona lockerungen bayern  13050
#   5              reproduktionszahl corona   9700
#   6        corona app der bundesregierung   5350
#   7          corona warn app installieren   4350
#   8               300€ kinderbonus corona   3550
#   9                  tönnies corona fälle   3400
#   10               konjunkturpaket corona   3400
#   11             corona app herunterladen   3100
#   12                     corona lockerung   2750
#   13                     corona regeln bw   2650
#   14  schleswig holstein corona tourismus   2250
#   15                    leopoldina corona   2250
#   16                   impfpflicht corona   2000
#   17         corona beschränkungen bayern   1550
#   18                 bayern corona regeln   1400
#   19                 corona verordnung bw   1250
#   20      corona regeln baden württemberg   1150
#   21                 corona regeln hessen   1100
#   22                    corona regeln nrw   1000
#   23                    kindergeld corona    950
#   24                        corona regeln    850}}

# %% [markdown]
# ### Comparing popularity of programming languages (interest over time)

# %%
pytrend = TrendReq(hl='en-US', tz=360)
keywords = ['Python', 'R','Fortran','HTML']

# build the payload
pytrend.build_payload(
     kw_list=keywords,
     cat=0,
     timeframe='today 5-y',
     geo='TW',
     gprop='')

# get the interest over time
data = pytrend.interest_over_time()

data= data.drop(labels=['isPartial'],axis='columns')

data.plot(title = 'Python vs R vs HTML vs Fortran in last 5 years on Google Trends ',figsize=(8,6));

# %%
CODES=pd.DataFrame( [pytrend.suggestions(keyword=i)[0] for i in keywords])
CODES
# Out:
#          mid    title                  type
# 0   /m/05z1_   Python  Programming language
# 1  /m/0212jm        R  Programming language
# 2   /m/02_94  Fortran  Programming language
# 3   /m/03g20     HTML  Programming language

# %% [markdown]
# Spooky plot style? Later we will learn how to modify plot styles.

# %%
# %matplotlib inline

import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.rcParams['font.size'] = 10
mpl.rcParams['figure.dpi'] = 120.
plt.style.use("seaborn-dark")

for param in ['figure.facecolor', 'axes.facecolor', 'savefig.facecolor']:
    plt.rcParams[param] = '#212946'  # bluish dark grey
for param in ['text.color', 'axes.labelcolor', 'xtick.color', 'ytick.color']:
    plt.rcParams[param] = '0.9'  # very light grey

colors = [
    '#08F7FE',  # teal/cyan
    '#FE53BB',  # pink
    '#F5D300',  # yellow
    '#00ff41', # matrix green
]
n_lines = 10
diff_linewidth = 1.05
alpha_value = 0.03
fig, ax = plt.subplots()
for n in range(1, n_lines+1):
    data.plot(
            linewidth=2+(diff_linewidth*n),
            alpha=alpha_value,
            legend=False,
            ax=ax,
            color=colors)
data.rolling(7).mean().plot( ax=ax, color=colors,figsize=(6,4),title = 'Python vs R vs HTML in last 5 years on Google Trends ')
ax.grid(color='#2A3459')

# %% [markdown]
# ### Daily Search Trends

# %% [markdown]
# Now let us get the top daily search trends worldwide. To do this we have to use the trending_searches() method. If you want to search worldwide just don’t pass any parameter.

# %%
# Get Google Hot Trends data
pytrend.trending_searches(pn='germany').head(10)
# Out:
#                        0
# 0            Naya Rivera
# 1         Koblenz Corona
# 2       Sabia Boulahrouz
# 3              Liverpool
# 4           FC Barcelona
# 5  Artemisia Gentileschi
# 6                Serbien
# 7                Havertz
# 8             Mary Trump
# 9        Fernando Alonso

# %% [markdown]
# ### Impact of Pandemic on people's interest

# %%
pytrend = TrendReq(hl='en-US', tz=360)

KEYWORDS=['Zara','H&M','AMAZON','TESLA']
CODES=pd.DataFrame( [pytrend.suggestions(keyword=i)[0] for i in KEYWORDS])
CODES
# Out:
#           mid       title                     type
# 0   /m/044_xs        Zara          Apparel company
# 1   /m/01d8pr         H&M  Clothing retail company
# 2    /m/0mgkg  Amazon.com       E-commerce company
# 3  /m/0j6n6s8       Tesla          Automobile make

# %%
EXACT_KEYWORDS=CODES['mid'].to_list()
DATE_INTERVAL='2017-01-01 2020-05-23'

COUNTRY=["US","DE",'IT'] #Use this link for iso country code

CATEGORY=0 # Use this link to select categories

SEARCH_TYPE='' #default is 'web searches',others include 'images','news','youtube','froogle' (google shopping)

# %%
Individual_EXACT_KEYWORD = list(zip(*[iter(EXACT_KEYWORDS)]*1))
Individual_EXACT_KEYWORD = [list(x) for x in Individual_EXACT_KEYWORD]

dicti = {}
i = 1
for Country in COUNTRY:
    for keyword in Individual_EXACT_KEYWORD:
        time.sleep(1)
        pytrend.build_payload(kw_list=keyword, 
                              timeframe = DATE_INTERVAL, 
                              geo = Country,
                              cat=CATEGORY,
                              gprop=SEARCH_TYPE) 
        dicti[i] = pytrend.interest_over_time()
        i+=1
df_trends = pd.concat(dicti, axis=1)
df_trends.columns = df_trends.columns.droplevel(0) #drop outside header
df_trends = df_trends.drop('isPartial', axis = 1) #drop "isPartial"
df_trends.reset_index(level=0,inplace=True) #reset_index
col = ['date']
for country in COUNTRY:
    for name in KEYWORDS:
        col.append(name+'-'+country)

df_trends.columns= col
df_trends.index=df_trends['date']
df_trends.drop('date',axis=1,inplace=True)

# %%
df_trends
# Out:
#             Zara-US  H&M-US  AMAZON-US  TESLA-US  Zara-DE  H&M-DE  AMAZON-DE  \
# date
# 2017-01-01       52      25         63        11       57      73         54
# 2017-01-08       50      23         60        10       50      66         51
# 2017-01-15       49      23         57        10       52      64         51
# 2017-01-22       48      23         55        10       49      64         49
# 2017-01-29       43      23         54        10       48      67         51
# ...             ...     ...        ...       ...      ...     ...        ...
# 2020-04-19       29      21         89        12       50      76         64
# 2020-04-26       34      23         90        15       51      71         62
# 2020-05-03       34      22         89        15       48      60         58
# 2020-05-10       34      22         89        19       50      62         56
# 2020-05-17       38      25         87        17       54      65         56
#
#             TESLA-DE  Zara-IT  H&M-IT  AMAZON-IT  TESLA-IT
# date
# 2017-01-01        20       63      69         39        39
# 2017-01-08        17       44      56         37        46
# 2017-01-15        19       38      46         36        24
# 2017-01-22        21       35      43         35        25
# 2017-01-29        18       36      43         36        26
# ...              ...      ...     ...        ...       ...
# 2020-04-19        38       34      65         73        21
# 2020-04-26        45       38      67         71        21
# 2020-05-03        42       39      65         67        23
# 2020-05-10        37       40      64         63        21
# 2020-05-17        32       46      73         59        33
#
# [177 rows x 12 columns]

# %%
df_trends[['AMAZON-US','AMAZON-IT','AMAZON-DE']].rolling(7).mean().plot()

# %%
df_trends[['Zara-US','Zara-IT','Zara-DE']].rolling(7).mean().plot()

# %%
df_trends[['TESLA-US','TESLA-IT','TESLA-DE']].rolling(7).mean().plot()

# %% [markdown]
# Another Example:
# https://towardsdatascience.com/heartbreak-monday-blues-and-pytrends-f1a398591a79

# %% [markdown]
# 'Popular times' feature of Google is not available within the Google Places API. However there is another way: https://github.com/m-wrzr/populartimes.

# %% [markdown]
# **Before we continue with Google's Places API we will take a look at other Python modules.**

# %% [markdown]
# ## Google Places API

# %% [markdown]
# How to get all the restaurants in a radius of 1km from my current locations (with the highest rating,...)? https://www.google.com/maps/place/Dresden/@51.0769658,13.6325012

# %% [markdown]
#  A detailed instruction can be found [here](https://python.gotrained.com/google-places-api-extracting-location-data-reviews/).

# %% [markdown]
# You should do:
# - Create a new project
# - enable APIs and services and get the API key!

# %% [markdown]
# https://console.developers.google.com/projectselector2/apis/
# <img src ='img/google_api_1.png'>

# %% [markdown]
# Select the Google places API and activate it.
# <img src ='img/google_api_2.png'>

# %% [markdown]
# Here is the documentary:
# https://developers.google.com/places/web-service/intro

# %% [markdown]
# Let us import a csv file and see what it contains:

# %%
dresden_nb = pd.read_csv('data/dresden_nb.csv',index_col=0)

# %%
dresden_nb
# Out:
#                                                         Post_code   latitude  \
# Neighborhood
# Albertstadt                                                 01099  51.083220
# Altfranken                                                  01156  51.034636
# Äußere Neustadt                                      01097, 01099  51.067186
# Blasewitz/Neugruna                     01277, 01279, 01307, 01309  51.044033
# Briesnitz                                            01157, 01169  51.068931
# ...                                                           ...        ...
# Tolkewitz/Seidnitz-Nord                              01277, 01279  51.034092
# Trachau                                              01129, 01139  51.100235
# Weißig                                                      01328  51.060894
# Weixdorf                                                    01108  51.152801
# Wilsdruffer Vorstadt/Seevorstadt-West         01067, 01069, 01159  51.050314
#
#                                        longitude
# Neighborhood
# Albertstadt                            13.768608
# Altfranken                             13.643747
# Äußere Neustadt                        13.752811
# Blasewitz/Neugruna                     13.811145
# Briesnitz                              13.664462
# ...                                          ...
# Tolkewitz/Seidnitz-Nord                13.817731
# Trachau                                13.702966
# Weißig                                 13.897644
# Weixdorf                               13.791666
# Wilsdruffer Vorstadt/Seevorstadt-West  13.724839
#
# [68 rows x 3 columns]

# %%
import folium
lat_dd,long_dd = 51.050314, 13.724839

map_Dresden = folium.Map(location=[lat_dd, long_dd], zoom_start=12)
# marker_cluster = MarkerCluster().add_to(m)

# add markers to map
for lat, lng, city_part in zip(dresden_nb['latitude'], dresden_nb['longitude'], dresden_nb.index):
    label = '{}'.format(city_part)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
#         popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False,popup=label).add_to(map_Dresden)
    
map_Dresden
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# This function is needed to access Google Places API

# %%
import json
import requests
import time
from api_keys import api_key_2

# here is my private api_key, please do use your own
API_KEY = api_key_2

# %% [markdown]
# Let us try to get some information out of Google's Places API

# %%
lat_dd,long_dd = 51.050314, 13.724839
location = str(lat_dd) + "," + str(long_dd)

endpoint_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

params = {'location': location,
            'radius': '300',
            'types': 'restaurant',
            'key': API_KEY }

res = requests.get(endpoint_url,  params)

results =  json.loads(res.content)
results
# Out:
# {'html_attributions': [],
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 51.0486149, 'lng': 13.7224103},
#     'viewport': {'northeast': {'lat': 51.0502507802915,
#       'lng': 13.7236592302915},
#      'southwest': {'lat': 51.0475528197085, 'lng': 13.7209612697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '33fe4c93514b5746834e5ab4b52d47347143889b',
#    'name': 'Restaurant Lampenfieber',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 960,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105752422972608002795">Restaurant Lampenfieber</a>'],
#      'photo_reference': 'CmRaAAAAITqZE6_cB7FkqW567zFuy6LgADQDjeem7loSodCYwqyjagBNbmp18N_vFMApFJ5RLt0Alk7uIeQX3wLrfARRXyeXJYsUimj23w4_W_Owuv3ON-PFImF4RkOlBX2UzodrEhDMbAzLa48bCy5VN8LYmbLpGhSpfumbQi_QI8pyoL5zD28yFjIm2Q',
#      'width': 651}],
#    'place_id': 'ChIJTZqWpHzPCUcR6fVYc55KYjU',
#    'plus_code': {'compound_code': '2PXC+CX Dresden, Germany',
#     'global_code': '9F3M2PXC+CX'},
#    'rating': 3.6,
#    'reference': 'ChIJTZqWpHzPCUcR6fVYc55KYjU',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 25,
#    'vicinity': 'Freiberger Straße 39, Dresden'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 51.0487705, 'lng': 13.7218145},
#     'viewport': {'northeast': {'lat': 51.0500397302915,
#       'lng': 13.7227623802915},
#      'southwest': {'lat': 51.04734176970851, 'lng': 13.7200644197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': 'd30edf48549b62674c01185c40c6ebe680ef58b0',
#    'name': 'Fu Long',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4608,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115326417269130306743">Andre Hanitz</a>'],
#      'photo_reference': 'CmRaAAAA_6sUYS5z_yyEg1d6QcAfnO9wj0wcy8khYaCLqVrKV8jmmeYT0ADcY9frm7qYT7aowbOtqR5tjZ076c8MuWEExP2tykNQ1QIkNcR2POXl5Ya9l0rnbx-h0O13Fn1-j4rQEhDEpFH-tOs7ljtmmf8qLnM0GhTBi5AbeDkNw6PfxE9Xl4d-iiRb-w',
#      'width': 3456}],
#    'place_id': 'ChIJV9qFm3zPCUcRPNB4ZjRtfVs',
#    'plus_code': {'compound_code': '2PXC+GP Dresden, Germany',
#     'global_code': '9F3M2PXC+GP'},
#    'rating': 3.2,
#    'reference': 'ChIJV9qFm3zPCUcRPNB4ZjRtfVs',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 51,
#    'vicinity': 'Ammonstraße 70, Dresden'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 51.0486072, 'lng': 13.7218679},
#     'viewport': {'northeast': {'lat': 51.0504006302915,
#       'lng': 13.7229867802915},
#      'southwest': {'lat': 51.0477026697085, 'lng': 13.7202888197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '7c95da63d4adcb335a9184c74388c239c3ec04ca',
#    'name': 'Mai An Sushi',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 566,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110042289307392738970">Mai An Sushi</a>'],
#      'photo_reference': 'CmRaAAAAlG_9Xjb8g0GtP1bS6c889n1_gUMlh6OEpqQgN1UMBsjCUa0RnOcrZf88m-_HJJ2F1nsqChmKUaQbQBHXF51wTQ8LTrcrzxZHy-TzUc0ve0WjJZnPqmm9fH67t9aoZmBfEhArjbivLe2u0urS1JRxzk_fGhRdWmBK29aX8DJReeLP7rMo9NWo7g',
#      'width': 849}],
#    'place_id': 'ChIJd2c9fHvPCUcRz-tIYZZ34jM',
#    'plus_code': {'compound_code': '2PXC+CP Dresden, Germany',
#     'global_code': '9F3M2PXC+CP'},
#    'rating': 4.4,
#    'reference': 'ChIJd2c9fHvPCUcRz-tIYZZ34jM',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 158,
#    'vicinity': 'Freiberger Straße 39, Dresden'}],
#  'status': 'OK'}

# %% [markdown]
# This is a bit messy. Let's write a function that calls the Google Places API and writes the results in a pandas DataFrame.

# %%
def get_places(lat,long, types, pages , radius):
    places = []
    location = str(lat) + "," + str(long)
    endpoint_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    params = {
            'location': location,
            'radius': radius,
            'types': types,
            'key': API_KEY
        }

    res = requests.get(endpoint_url, params = params)
    results =  json.loads(res.content)
    places = places + results['results']
    time.sleep(2.2)
    while "next_page_token" in results:
        params['pagetoken'] = results['next_page_token'],
        res = requests.get(endpoint_url, params = params)
        results = json.loads(res.content)
        places = places + results['results']
        time.sleep(2.2)
    return places

# %% [markdown]
#  Each search can return maximum 60 results and there will be 20 results per page. So you will need to paginate through the results if there is more that 20 results in your search. If there is more pages the API will return  next_page_token  with the results and you have to submit this value to the API with the same search parameters to get the rest of the results.
# Note: There is a delay until the  next_page_token is issued and validated. So you need to put a small sleep time like 2 seconds between each request. Otherwise, you will get an  INVALID_REQUEST status.

# %% [markdown]
# The next function parse the json file to a DataFrame:

# %%
def parse_place_to_list(place, type_name,hood):
    return [
        hood,
        place['name'],
        place['place_id'],
        place['geometry']['location']['lat'],
        place['geometry']['location']['lng'],
        type_name,
#         place['rating'],
#         place['user_ratings_total'],
#         place['icon']
    ]

# %% [markdown]
# Let us try it out:

# %%
alt_neu_stadt = dresden_nb.loc[['Innere Altstadt','Innere Neustadt','Äußere Neustadt','Striesen-West']]
alt_neu_stadt
# Out:
#                     Post_code   latitude  longitude
# Neighborhood
# Innere Altstadt  01067, 01069  51.051112  13.739014
# Innere Neustadt  01097, 01099  51.060078  13.744628
# Äußere Neustadt  01097, 01099  51.067186  13.752811
# Striesen-West    01307, 01309  51.048649  13.782633

# %%
lat_dd,long_dd = 51.050314, 13.724839
map_Dresden = folium.Map(location=[lat_dd, long_dd], zoom_start=13)

# add markers to map
for lat, lng, city_part in zip(alt_neu_stadt['latitude'], alt_neu_stadt['longitude'], alt_neu_stadt.index):
    label = '{}'.format(city_part)
    label = folium.Popup(label, parse_html=True)
    
    folium.CircleMarker([lat, lng],
        radius=5, fill=True,fill_opacity=0.7).add_to(map_Dresden)
    
    folium.Circle([lat, lng],
                    radius=490,fill=True,fill_opacity=0.3,popup=label
                   ).add_to(map_Dresden)
    
map_Dresden
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# What about all the restaurants in this four neighborhoods?

# %%
data = []
radius = 490
pages = 3
place_type = 'restaurant'

# get the restaurants
names = alt_neu_stadt.index

for name in names:
    print ('Getting places for ',name)
    lat, lng = alt_neu_stadt.loc[name]['latitude'] ,alt_neu_stadt.loc[name]['longitude']

    result = get_places(lat,lng,place_type, pages,radius)

    # this converts the json data to a list
    result_parsed = list(map(lambda x: parse_place_to_list(x, place_type, name ), result))
    data = data + result_parsed


dd_ggl = pd.DataFrame(data, columns=['Neighborhood','Venue', 'place_id', 'latitude', 'longitude', 'place_type'])
dd_ggl
# Out:
# Getting places for  Innere Altstadt
# Getting places for  Innere Neustadt
# Getting places for  Äußere Neustadt
# Getting places for  Striesen-West
#         Neighborhood                                        Venue  \
# 0    Innere Altstadt           Sophienkeller im Taschenbergpalais
# 1    Innere Altstadt        Coselpalais - Restaurant & Grand Café
# 2    Innere Altstadt               Augustiner an der Frauenkirche
# 3    Innere Altstadt                     Felix im Lebendigen Haus
# 4    Innere Altstadt              Shamrock Irish Bar & Restaurant
# ..               ...                                          ...
# 170    Striesen-West                                   Mensologie
# 171    Striesen-West  Unser Bäcker - Bäckerei und Konditorei GmbH
# 172    Striesen-West                      NEWROZ Dürüm-Kebap-Haus
# 173    Striesen-West                            Restaurant Daniel
# 174    Striesen-West                      Royal - Kebab - Dresden
#
#                         place_id   latitude  longitude  place_type
# 0    ChIJe-d6MmbPCUcRrqzjBLVTbKk  51.051873  13.734910  restaurant
# 1    ChIJQXEkyELPCUcRiFqB-XclnmI  51.052202  13.742471  restaurant
# 2    ChIJQXEkyELPCUcRux2IlVhZoJI  51.051493  13.742133  restaurant
# 3    ChIJ7U-7ymfPCUcRy_OtUvqSmrs  51.051614  13.734670  restaurant
# 4    ChIJe5JWNGbPCUcRgsN2caFryiQ  51.050793  13.736588  restaurant
# ..                           ...        ...        ...         ...
# 170  ChIJ8eCoT7fICUcR4NVyY7KVcgc  51.052692  13.784333  restaurant
# 171  ChIJT2gtfq_ICUcRZCEB1yyaFG4  51.044460  13.781114  restaurant
# 172  ChIJ8ZgqBrDICUcRnfCgbnXqCbc  51.047698  13.782730  restaurant
# 173  ChIJi9OXLWvPCUcROM7TFidJ1JI  51.051014  13.777486  restaurant
# 174  ChIJj4j5J7fICUcRULYwKPeIkl0  51.052897  13.781898  restaurant
#
# [175 rows x 6 columns]

# %% [markdown]
# The place_id is needed if you want to have further information about the place (ratings, address, pictures,...).

# %%
dd_ggl['Neighborhood'].value_counts()
# Out:
# Innere Altstadt    60
# Äußere Neustadt    60
# Innere Neustadt    48
# Striesen-West       7
# Name: Neighborhood, dtype: int64

# %%
from folium.plugins import MarkerCluster

map_Dresden = folium.Map(location=[lat_dd, long_dd], zoom_start=13)

incidents = MarkerCluster().add_to(map_Dresden)
# add markers to map
for lat, lng, name in zip(dd_ggl['latitude'], dd_ggl['longitude'], dd_ggl['Venue']):
    label = '{}'.format(name)
    label = folium.Popup(label, parse_html=True)
    
    
    folium.Marker([lat, lng],icon=None,popup=label).add_to(incidents)

map_Dresden
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Let us look for a bit more information about the city and explore it.

# %%
places_types = ['art_gallery','airport','bank','bar','beauty_salon','book_store','bakery','bus_station',
            'cafe','church','doctor', 'dentist', 'gym','hair_care','hospital','pharmacy','pet_store',
            'night_club','movie_theater','school','shopping_mall','supermarket','city_hall',
            'clothing_store','electronics_store','gas_station','meal_delivery', 'meal_takeaway',
            'museum','park','restaurant','train_station','car_dealer', 'car_rental','casino',
               'car_repair', 'car_wash','city_hall','drugstore','jewelry_store','library','parking','stadium','tourist_attraction']
places_types = set(places_types) # deletes repated entries

data = []
radius = 490  # radius of the search
pages = 3   # per page 20 entries , max 3 pages or 60 entries per query 

# for name in dresden_nb.index:
#     print("Getting into "  + name)
#     for place_type in places_types:
#         lat, lng = dresden_nb.loc[name]['latitude'] ,dresden_nb.loc[name]['longitude']
#         result = get_places(lat,lng,place_type, pages,radius)
        
#         result_parsed = list(map(lambda x: parse_place_to_list(x, place_type, name ), result))
#         data += result_parsed
# dd_ggl = pd.DataFrame(data, columns=['Neighborhood','Venue', 'place_id', 'latitude', 'longitude', 'place_type'])
# dd_ggl.to_csv('data/dresden_venues_google_p3_r490.csv')

# %%
# as the above takes quite a while we will load the result
dd_ggl = pd.read_csv('data/dresden_venues_google_p3_r490.csv')

# %%
dd_ggl[['Neighborhood','place_type']].groupby('place_type').describe().head(10)
# Out:
#              Neighborhood
#                     count unique                  top freq
# place_type
# airport                 3      2  Hellerau/Wilschdorf    2
# art_gallery            20      7      Innere Altstadt    6
# bakery                171     41      Innere Altstadt   22
# bank                  110     27      Innere Neustadt   22
# bar                   115     25      Äußere Neustadt   40
# beauty_salon           86     33          Löbtau-Nord   11
# book_store             30     18      Innere Altstadt    4
# bus_station             7      5          Löbtau-Nord    2
# cafe                  183     36      Innere Altstadt   48
# car_dealer             68     31           Löbtau-Süd    9

# %%
dd_ggl[['Neighborhood','place_type']].groupby('place_type').count()
# Out:
#                     Neighborhood
# place_type
# airport                        3
# art_gallery                   20
# bakery                       171
# bank                         110
# bar                          115
# beauty_salon                  86
# book_store                    30
# bus_station                    7
# cafe                         183
# car_dealer                    68
# car_rental                    50
# car_repair                   196
# car_wash                      17
# casino                         3
# church                        76
# city_hall                     10
# clothing_store               208
# dentist                      235
# doctor                       682
# drugstore                     20
# electronics_store            185
# gas_station                   13
# gym                           58
# hair_care                    180
# hospital                      32
# jewelry_store                 66
# library                       16
# meal_delivery                 52
# meal_takeaway                 83
# movie_theater                  7
# museum                        31
# night_club                    14
# park                         111
# parking                       77
# pet_store                      8
# pharmacy                      69
# restaurant                   542
# school                       392
# shopping_mall                 13
# supermarket                  118
# tourist_attraction            56
# train_station                  4

# %% [markdown]
# Place details and further google API calls (https://developers.google.com/places/web-service/details).

# %%
def get_place_details(place_id, fields):
    endpoint_url = "https://maps.googleapis.com/maps/api/place/details/json"
    params = {
            'placeid': place_id,
            'fields': ",".join(fields),
            'key': API_KEY
        }
    res = requests.get(endpoint_url, params = params)
    place_details =  json.loads(res.content)
    return place_details

# %% [markdown]
# Now  places variable contains our search results. Every place has a  place_id and we will use the place identifier to retrieve more details about it.
#
# Let’s define the fields which we want to retrieve.
#
# fields = ['name', 'formatted_address', 'international_phone_number', 'website', 'rating', 'review']
#
# And finally retrieve the details.

# %% [markdown]
# Show all bakeries in the search:

# %%
bakery = dd_ggl[dd_ggl['place_type']=='bakery']
bakery
# Out:
#       Unnamed: 0                           Neighborhood  \
# 267          267                        Äußere Neustadt
# 268          268                        Äußere Neustadt
# 269          269                        Äußere Neustadt
# 270          270                        Äußere Neustadt
# 271          271                        Äußere Neustadt
# ...          ...                                    ...
# 4251        4251                Tolkewitz/Seidnitz-Nord
# 4252        4252                Tolkewitz/Seidnitz-Nord
# 4339        4339  Wilsdruffer Vorstadt/Seevorstadt-West
# 4340        4340  Wilsdruffer Vorstadt/Seevorstadt-West
# 4341        4341  Wilsdruffer Vorstadt/Seevorstadt-West
#
#                                          Venue                     place_id  \
# 267                     Bäckerei Otte Backland  ChIJiRXB_OmQcUERI5WsshmO5Gc
# 268                           Richter Bäckerei  ChIJL7xkWTzPCUcRN4JKIpSLZsg
# 269                   Bäckerei Konditorei Graf  ChIJE1CAKOqQcUERieQyuCgGQJw
# 270                    Fiete Behnersens V-Cake  ChIJS8Wj2D7PCUcR2zbzGlgSO2M
# 271                                   BackWerk  ChIJ_yR4XT3PCUcR_Ab6O4NrQ7Q
# ...                                        ...                          ...
# 4251               Bäckerei Konditorei Siemank  ChIJnartsH_ICUcRYeFsFjdyCHI
# 4252                      Bäckerei Siemank OHG  ChIJp5wKjnKQcUERJlLWhWXJ3xE
# 4339                            Bakeries Laube  ChIJbZqrnnzPCUcRK7mVvl4eEEg
# 4340                    Dresdner Backhaus GmbH  ChIJk0912GTPCUcROVJnwk6dWXw
# 4341  Bäckerei und Konditorei Schwerdtner GmbH  ChIJeTt_Tm7PCUcRZTd59glmy_Y
#
#        latitude  longitude place_type
# 267   51.067254  13.754189     bakery
# 268   51.067719  13.754841     bakery
# 269   51.065756  13.750356     bakery
# 270   51.063973  13.752530     bakery
# 271   51.070877  13.750537     bakery
# ...         ...        ...        ...
# 4251  51.033291  13.823118     bakery
# 4252  51.033590  13.823135     bakery
# 4339  51.048164  13.721536     bakery
# 4340  51.050547  13.725218     bakery
# 4341  51.053178  13.724699     bakery
#
# [171 rows x 7 columns]

# %%
from folium.plugins import MarkerCluster

map_Dresden = folium.Map(location=[lat_dd, long_dd], zoom_start=13)

incidents = MarkerCluster().add_to(map_Dresden)
# add markers to map
for lat, lng, name in zip(bakery['latitude'], bakery['longitude'], bakery['Venue']):
    label = '{}'.format(name)
    label = folium.Popup(label, parse_html=True)
    
    
    folium.Marker([lat, lng],icon=None,popup=label).add_to(incidents)

map_Dresden
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
